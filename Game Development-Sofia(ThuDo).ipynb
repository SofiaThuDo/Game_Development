# %%
"""
INDIVIDUAL ASSIGNMENT 
@author: thu.do (sofia)

"""

#Docstring
#Introduction and Control errors
"""
DocString:
    A) INTRODUCTION           
The purpose of the game is to find the True King of the Ocean 
to save Atlantis from doom.
This planet is an amazing place to live … but it needs your help. 
There are four major environmental challenges facing our planet: 
climate change, pollution, habitat destruction, and declining biodiversity.
And our Kingdom has been destroying by human actions. 
You have to show the power of the King by your knowledge about Ocean through 4 rounds:

ROUND 1: OCEAN CREATURES
ROUND 2: OCEAN FACTS
ROUND 3: OCEAN PROBLEMS
ROUND 4: RESCUE THE QUEEN (Lucky stage)

    
    B) Known bug and/or errors: None
    
"""
#prompt user press ENTER to start the game
input(prompt = '<Press ENTER to continue:>\n')
from sys import exit
import random
import time

#define the function for the beginning of the game

def beginning():
    global ocean_host
    global contestant_name
    
    #Welcoming messages to the game
    print(f"""
                 _______________________________________
                                                    
                WELCOME TO 'AQUAMAN: KING OF THE ATLANTIS'
                 _______________________________________ 
                
    We are looking for the True King of the Ocean to save Atlantis from doom
    This planet is an amazing place to live … but it needs your help. 
    Your knowledge about Ocean & a little bit of luck will help you become our
                            OCEAN SUPERHERO!

                        ... {'@.@ ' * 5}...
                        
                        I'm the host of the ocean
    Everybody, please say my name loudly! Myyyy nameee issss {'?'*10}
""")
    
    #prompt user to input the name of the host
    ocean_host = input(prompt = """
    Enter the name of ocean host:\t""")
    
    #print the name of the host
    print(f"""
    You're absolutely right! My name is {ocean_host.capitalize()}. 
    And I'd like to know about yours, too 
""")
    
    #promp user to input his/her name
    contestant_name = input(prompt = """
    What is your name?\t""")
    
    print( f""" 
    Hi, {contestant_name.upper()}. 
                                 Are you ready     
                             TO BECOME OUR MAJESTY?
                             ---------***---------
                                LET'S GET START
    """ )
    input(prompt = '<Press ENTER to start>\n')     #prompt user press ENTER to start 1st stage
    room_1()                                       #call room 1 to start the 1st stage
    

#Start of the 1st stage: OCEAN CREATURES!
#define the function room 1 for stage 1
def room_1():
    
    #Introduction of the 1st stage 
    print(f"""
{ocean_host.capitalize()}:
        
                            ___       ___    ___
                           /   \     /   \  /   \   |        
                           \___/ ___ \___/  \___/   |     
                           /   \/   \/   \  |   |   |     
                           \___/\___/\___/  |   |   |    
                           /   \     /   \  |   |   |
                           \___/     \___/  |___|   .

                           WELCOME TO THE FISRT STAGE
                             _____________________
                            |       STAGE 1       |
                            |_____OCEAN CREATURE__|
                         
{'*' * 90}            
    At this stage,
    You have to prove your abilities of understanding our marine life. 
    There are 3 multiple choice questions and you need 3 consecutively correct answers 
    to pass the stage
{'_' * 90}

                 Are you ready for the question, {contestant_name.upper()}?
""")
    
    input(prompt = '<Press ENTER to continue>\n')

    #Using 7 variables' names to minimize the text in nested conditional statement
    #Indented to get the same line in output
    question_1 = """
                Question 1: Which is the largest of all sharks?
                A. Great white shark
                B. Whale shark
                C. Tiger shark """
    question_2 = """
                Question 2: Sharks have existed for approximately how long?
                A. 350M years
                B. 10M years
                C. 1M years """
    question_3 = """
                Question 3: The blue whale is the world's largest animal. 
                What other amazing feature is it known for?
                A. One of the fastest animals
                B. One of the loudest animals
                C. One of the lightest animals"""
    
    correct_1 = """
                Congratulations, correct choice!  
                The whale shark can weigh as much as 13 tons, 
                which is the same as 2 African elephants
                """
    
    correct_2 = """
                You are awesome- Thats correct! 
                These sophisticated creatures have lived on Earth for 350 millions years. 
                They deserve to remain here & we humans are entrusted to make sure that they do
                """
    
    correct_3 = """
                Amazing! Correct answer
                The blue whale is the loudest animal on the planet
                At 188 decibels, its low-frequency whistle is louder than a jet engine
                and can be heard hundreds of miles away. That's loud!!!
                """
    
    incorrect_answer = """
                Opps, incorrect answer """
    
    #start question 1 
    print(question_1)
    
    choice_1 = input(prompt = "Enter your answer: ")         #propmt user to enter the answer for question 1
    choice_1 = choice_1.casefold()                           #convert the input of user to control the answer
    
    #conditional statement for question 1
    if choice_1 == 'b' or 'whale' in choice_1:
        print(correct_1)                                     #print the correct answer for Q1
        time.sleep(3)                                        #time sleep to enhance user experienece
        
        #start question 2 when user got the right answer in Q1 
        print(question_2)
        
        choice_2 = input(prompt = 'Enter your answer: ')     #propmt user to enter the answer for question 2
        choice_2 = choice_2.casefold()                       #convert the input of user to control the answer
        
        #start nested conditional statement (question 2)
        if choice_2 == 'a' or '350m' in choice_2 or choice_2 == '350' \
                        or '350 m' in choice_2:
            print(correct_2)                                 #print the correct answer for Q2
            time.sleep(3)                                    #time sleep for question 2
                     
            #start question 3 when user got the correct answer in Q2
            print(question_3)
            
            choice_3 = input(prompt = "Enter your answer: ") #propmt user to enter the answer for question 3
            choice_3 = choice_3.casefold()                   #convert the input of user to control the answer
            
            #start nested conditional for (question 3)
            if choice_3 =='b' or 'loudest' in choice_3:
                print(correct_3)                             #print the correct answer for Q3
                time.sleep(3)                                #time sleep before the 2nd stage start
                input(prompt = '<Press ENTER continue>\n')   #prompt user press ENTER to continue next stage
                room_2()                                     #Call room 2 when all the answers are correct. 
                #End of stage 1
                
            elif choice_3 == 'a' or 'fastest' in choice_3:
                print(incorrect_answer)
                fail()                                       #call fail whenever the answer is incorrect  
            
            elif choice_3 == 'c' or 'lightest' in choice_3:
                print(incorrect_answer)
                fail()                                       #call fail whenever the answer is incorrect 
            
            else:
                print("""
Invalid result.\nPlease try this stage again""")
                
                input(prompt = '<Press any ENTER to go back stage 1>\n')
                
                room_1()                                     #Call room 1 when invalid answer happened (play the stage again)
            #end of nested conditional statement (question 3)
            
        elif choice_2 == 'b' or '10m' in choice_2 or choice_2 == '10' \
                          or '10 m' in choice_2:
            print(incorrect_answer)                           
            fail()                                           #call fail whenever the answer is incorrect          
    
        elif choice_2 == 'c' or '1m' in choice_2 or choice_2 == '1' \
                          or '1 m' in choice_2:
            print(incorrect_answer)                          
            fail()                                           #call fail whenever the answer is incorrect                               
            
        else:  
            print(f"""
Hey {contestant_name.capitalize()}, invalid result\nPlease try this stage again""")
            
            input(prompt = '<Press ENTER to go back stage 1>\n')
            
            room_1()                                         #Call room 1 when invalid answer happened (play the stage again)
        #end of nested conditional statement (question 2)
            
    elif choice_1 == 'a' or 'great' in choice_1 or 'white' in choice_1:
        print(incorrect_answer)
        fail()                                               #call fail whenever the answer is incorrect
    
    elif choice_1 == 'c' or 'tiger' in choice_1:
        print(incorrect_answer)
        fail()                                               #call fail whenever the answer is incorrect
    
    else:
        print(f"""
Invalid result.\n {contestant_name.capitalize()}, Please try this stage again""")
        
        input('<Press ENTER to go back stage 1>\n')
     
        room_1()                                             #Call room 1 to let user play again when invalid answer happened
    #End of conditional statement for question 1

    
#Start of the second satge of the game: Ocean & Human
def room_2():
    
    # print the introduction of the stage
    print(f"""
{ocean_host.capitalize()}:
                         ______
                        |
                        |
                        |___              |  |
                        |           __  _ |  |   _     -|-
                        |       \/ |   |_ |  |  |_ |\ | |
                        |______ /\ |__ |_ |_ |_ |_ | \| |_

                                 {contestant_name.upper()}, YOU ARE IN         
                              _____________________
                             |       STAGE 2       |
                             |_____OCEAN FACTS_____|

{'*' * 90}
    At this stage, you have to answer the question by filling the blanks.
    There are 2 chances for you to guess the correct answer.

                          WISH YOU LUCK! {contestant_name.upper()}
{'_' * 90}
                    
""")
    #prompt the user to press ENTER to start the 2nd stage (room 2)
    input(prompt = "<Press any key to continue>\n")
    
    #assign the information to the variables
    question_4 = """
                 What is the most frequent found object in the beach cleanups?
                 _____
                 """
    question_5 = """
                 Where does the majority of plastic waste end up? _____
                 """
    question_6 = """
                 Tsunamis are caused by ______ on the ocean floor
                 """
    times = 2
    
    #create a list of questions
    lst = [question_4, question_5, question_6]
    
    import random
    #random choose a question in the list
    question_room2 = random.choice(lst)
    
    #Conditional statement for the 1st question in the list (variable name: question_4) 
    if question_room2 == lst[0]:
        print(question_4)                                          #print the question 4 if random choose the 1st element of list
        
        #while loop for the 1st question with 2 chances of guessing
        while times >= 0:
            answer_4 = input(prompt = 'Enter your answer: ')       #prompt user to enter the answer for Q4
            answer_4 = answer_4.casefold()                         #control the input by casefold converting
            
            #nested conditional statemnte for the answer 
            if 'plastic' in answer_4:
                print("""
                Exactly! 
                Plastic is the major problem, with about 8 million metric tons
                of plastic waste entering the ocean every year! We can help
                our ocean by using less plastic or recycling whenever we can.""")
                time.sleep(3)                                      #sleep time to enhance user experience
                input(prompt = "press ENTER to continue\n")
                room_3()                                           #call room 3 when user get the right answer
                
            elif 'plastic' not in answer_4:
                times -= 1
                
                #nested conditional statement controlling the chance remains
                if times != 0:
                    print(f"""
                Opps, that's wrong! you have {times} time left""")
                    
                else:
                    print("""
                Sorry! you have no more chance!""")
                    fail()                                         #call fail when user has no more chance
                #end of nested conditional statement
                
            else:
                print("""
                Invalid entry! Try again""")
                input(prompt = "Press ENTER to back stage 2")
                room_2()                                           #call room 2 for user to play this stage again
            #end of nested condtional statement
    
    #Conditional statement for the 2nd question in the list (variable name: question_5)
    if question_room2 == lst[1]:
        print(question_5)                                          #print question 5 if random choice = 2nd element in list
        
        #while loop for the question 5 with 2 chances of guessing
        while times >= 0:
            answer_5 = input(prompt = 'Enter your answer: ')       #prompt user to answer Q5
            answer_5 = answer_5.casefold()                         #control the input by casefold (lowercase include special character)
            
            #nested conditional statemnte for the answer   
            if 'ocean' in answer_5:
                print(f"""
                Awesome {contestant_name.capitalize()}!
                Taking hundreds of years to break up, plastic is not going anywhere soon. 
                A majority of it ends up in the ocean through deliberate dumping 
                of garbage into waterways, inefficient waste infrastructure, and simple littering. 
                """)
                time.sleep(3)                                      #time sleep for 6 seconds (time to read the result)
                input(prompt = "Press ENTER to continue\n")        #prompt user press ENTER to continue next stage
                room_3()                                           #call room 3 if the answer is correct
            elif 'ocean' not in answer_5:
                times -= 1
                
                #nested conditional statement controlling the chance remains
                if times != 0:
                    print(f"""
                Incorrect answer! You have {times} time left """)  #the notification to let user know how many chance left
                    
                else:
                    print("""
                Sorry! You have no more chance""")
                    fail()                                         #Call fail function when user has no chance left
                #end of nested conditional statement
                
            else:
                print("""
                Invalid entry! Try again""")
                input(prompt = "Press ENTER to back stage 2")
                room_2()                                           #call room 2 for user to play this stage again
            #end of nested condtional statement   
                
    #Conditional statement for the 3rd question in the list (variable name: question_6)
    if question_room2 == lst[2]:
        print(question_6)                                          #print question 5 if random choice = last element in list
        
        #while loop for the question 6 with 2 chances of guessing
        while times >= 0:
            answer_6 = input(prompt = 'Enter your answer: ')       #prompt user to answer Q6
            answer_6 = answer_6.casefold()                         #convert the input by casefold
            
            #nested conditional statement for the answer     
            if 'earthquake' in answer_6:
                print(f"""
                Excellent, {contestant_name.capitalize()}!
                A tsunami is a series of waves in a water body 
                caused by the displacement of a large volume of water. 
                Earthquakes, volcanic eruptions and other underwater explosions above 
                or below water all have the potential to generate a tsunami 
                """)
                time.sleep(3)                                      #time sleep to enhance user experience
                input(prompt = "press ENTER to continue\n")        #prompt user press ENTER to continue next stage
                room_3()                                           #call room 3 if the answer is correct
            elif 'earthquake' not in answer_6:
                times -= 1
                
                #nested conditional statement controlling the chance remains
                if times != 0:
                    print(f"""
                Incorrect answer! You have {times} time left """)
                    
                else:
                    print("""
                Sorry! You have no more chance""")
                    fail()                                         #Call fail function when user has no chance left
                #end of nested conditional statement
                
            else:
                print("""
                Invalid entry! Try again stage 2""")
                input(prompt = "press ENTER to back stage 2") 
                room_2()                                           #call room 2 for user to play this stage again
            #end of conditional statement


#Start the 3rd stage
def room_3():
    
    #print the introduction and the rule of stage 3
    print(f"""
{ocean_host.capitalize()}:
    
                              _____________________
                             |       STAGE 3       |
                             |_____OCEAN PROBLEMS__|

                AMAZING! {contestant_name.upper()}. YOU ARE HALF WAY OF THE JOURNEY

                            ____ ____  ____     _____
                           |     |___| |__   /\   |
                           |  __ |   \ |    /==\  |
                           |___| |    \|___/    \ |
                       
                          
{'*' * 90}
    At this stage, you have to arrange the correct order of the answer.
    You will see a suggestion list and have 2 chances to guess the right order!
    The question is related to the ocean issues that the King have to solve 
    
                               YOU CAN DO IT!
{'_' * 90}
                                  
    """)
    
    input(prompt = "<Press ENTER continue>")                #prompt the user press ENTER to continue
    
    #assign information for variable's name question_7
    question_7 = "Arrange the top 3 of ocean issues in order of the most to the least serious one"
    
    #creat a list of factors causes ocean problems
    lst_2 = [["pollution", 2], 
             ["plastic", 1], 
             ["oil drilling", 5], 
             ["overfishing", 4], 
             ["warming", 3], 
             ["acidification",6]]
    
    oppotunity = 2
    
    #print the question 
    print("Question: " + question_7 +"\n")
    
    #Using for loop to access the element of the list
    for factor, place in lst_2:
        print(factor)                                       #print each factor in list
    
    #while loop to let the user have 2 times of guessing
    while oppotunity >= 0:
        #prompt user input the 1st rank issue
        range_1 = input(prompt = """\n
From the list below, enter the most serious factor:\n""")   #prompt user enter the 1st serious factor
        range_1 = range_1.casefold()                        #converting the 1st input of Q7                 
         
        #prompt user input the 2nd rank issue
        range_2 = input(prompt = """\n
From the list below, enter the 2nd serious factor:\n""")    #prompt user enter the 2nd serious factor
        range_2 = range_2.casefold()                        #converting the 2nd input for Q7
        
        #prompt user input the 3rd rank issue
        range_3 = input(prompt = """\n
From the list below, enter the 3rd serious factor:\n""")    #prompt user enter the 3rd serious factor
        range_3 = range_3.casefold()                        #converting the 3rd input for Q7
        
        #nested condtional to control the answer
        if "plastic" in range_1 and "pollution" in range_2 and "warming" in range_3:
            print(f"""
                COOL! {contestant_name.upper()}
                The order is plastic - pollution - global warming\n""")
            
            time.sleep(1)                                   #sleep for 1 second
            input(prompt = "press ENTER to continue\n")     #prompt user press ENTER to move to next stage
            room_4()                                        #call room 4 when 3 answer are correct
                
        elif "plastic" not in range_1 or "pollution" not in range_2 or "warming" not in range_3:
            oppotunity -= 1                                 #minus 1 times of oppotunity when user type the wrong input
            
            #nested conditional statement for the chance different than 0
            if oppotunity != 0:
                print(f"""
                Opps, sorry. It was not the right order.
                You have {oppotunity} times left""")        #confirm statement to let user know how many oppotunity left
                    
            else:
                print(f"""
                It was the wrong order again!
                Sorry! You have no more chance, {contestant_name.capitalize()}
                """)                                        #confirm statement will be printed when user has no more chance
                fail()                                      #call fail when the user has no more chance
            #end of nested conditional statement
            
        else:
            print("Something went wrong! please try again")
            input(prompt = "Press ENTER to get back stage 3\n")
            room_3()                                        #call room 3 for user to play this stage again
        #end of conditional statement
                      

# Start the last stage of the game- room 4
def room_4():
    #Introduction the rule for the final stage
    print(f"""
{ocean_host.capitalize()}:

                WOW, {contestant_name.upper()}! You are truly awesome to survive until now.

                         -------------***----------------   
                         |  WELCOME TO THE FINAL STAGE  |
                         --------------***---------------
                            RESCUE THE QUEEN OF ATLANTIS

            At this last stage, only luck can help you become the new King....
        
{'*' * 90}
    One of the most dangerous living creatures has locked the Queen for 1000 years.
    
    There are 10 gates and you have 2 chances to guess the right one.
    Let choose the lucky number that you believe she is there. 
                    
                            GOODLUCK! {contestant_name.upper()}
{'_' * 90}                    
    """)
    
    import random
    random.seed(508)                                   #control the random result 
    number = random.randint(a=1, b=10)                 #random choice between 1-10
    chance = 2                                         #set the variable for while loop
    
    #Using while loop for the lucky number gate - there are 2 chances
    while chance >= 0:
        
        #Using while True loop to control the input
        while True:
            
            #prompt the user to input the lucky number
            your_choice = input("Enter a number (1-10) that you believe the Queen is in: ")
            print(f"""
                You've input {your_choice}
                """)
            
            #Converting your_choice to type int
            try:
                your_choice = int(your_choice)
                
                #Nested conditional statement
                if your_choice == number:
                    
                    #print the statement if user won
                    print(f"""
                    EXACTLY, {contestant_name.upper()}. IT IS UNBELIEVABLE.""")
                    time.sleep(1)
                    win()                               #call the win function - end of the game
                    input("<Press any key to exit>\n")  #prompt user to press ENTER, exit the game
                    exit(0)
            
                elif your_choice != number:
                    chance -= 1                         #minus 1 chance when user guess incorecct number
                    
                    #Nested condtional statement 
                    if chance == 0:
                        #print the message when running out of chances
                        print(f"""
                Unfortunately {contestant_name.upper()}! 
                You have no more chance. 
                The Queen is in gate {number}
                The Ocean evil spirit will kill you\n""")
                        fail()                           #call fail function whenever user has no more chance
            
                    else:
                        #print the message to let user know how many chances left
                        print(f"""
                Opps, that's not the correct one, {contestant_name.capitalize()}.
                You have {chance} chance remains""") 
                    #End of the nested conditional statement
    
                else:
                    print("Something went wrong")
                    input(prompt = 'Press ENTER to get back the stage\n')
                    room_4()                            #call room 4 to play the stage again
                #End of the nested conditional statement
                
            except:
                print("""
                That wasn't a proper input. Please try again!""")
                input(prompt = 'Press ENTER to get back the stage\n')
                room_4()                                #call room 4 when they input non-numeric answers
        
#define the function fail
def fail():
    print(f"""
                                   ______________
                                   |  GAME OVER  |  
                                   |  GAME OVER  |
                                   |  GAME OVER  |
                                   # !!!!!!!!!!!!!!!  
                                   # !!!!!!!!!!!!!!!
                           
{'X' *90}
    
    """)
    #prompt user input the Yes/No option to play again
    yes_no = input("Do you want to play again? (Yes/No): ")
    yes_no = yes_no.casefold()
    
    #conditional statement
    if yes_no == 'yes':
        room_1()     #call room 1 when user say yes-play the game again
    else:
        print(f"""
                Thank for your time, {contestant_name.capitalize()}!
                Wish you learn something from the Ocean in this game""")
        input("<Press any key to exit>\n")
        exit(0)
    
#define the function win when user got all correct answer for 4 stages   
def win():
    print(f"""
                            {contestant_name.upper()}! CONGRATULATIONS {'!' * 5}
                            YOUR REWARD IS A GOLD TROPHY  
                        YOU ARE ATLANTIS HERO- TRULY NEW KING
                    
{'~~' * 45}
{'||' * 45}

                                |\/\/\\_____//\/\/|
                                \                /
                                 \              /
                                  \            /
                                   \          /
                                    \        /
                                     \      /

                                {contestant_name.upper()}! KING OF ATANTIS
""")

beginning()
# Out:
# <Press ENTER to continue:>
#
#
#                  _______________________________________
#
#                 WELCOME TO 'AQUAMAN: KING OF THE ATLANTIS'
#                  _______________________________________
#
#     We are looking for the True King of the Ocean to save Atlantis from doom
#     This planet is an amazing place to live … but it needs your help.
#     Your knowledge about Ocean & a little bit of luck will help you become our
#                             OCEAN SUPERHERO!
#
#                         ... @.@ @.@ @.@ @.@ @.@ ...
#
#                         I'm the host of the ocean
#     Everybody, please say my name loudly! Myyyy nameee issss ??????????
#
#
#     Enter the name of ocean host:	bee
#
#     You're absolutely right! My name is Bee.
#     And I'd like to know about yours, too
#
#
#     What is your name?	sofia
#
#     Hi, SOFIA.
#                                  Are you ready
#                              TO BECOME OUR MAJESTY?
# ...
